# %%
#statement to get the type of machine learning
type(phase)
# Out:
# str

# %%
#Entre phrase
phase='statistics sits at the heart of machin learning'
print(phase)
# Out:
# statistics sits at the heart of machin learning

# %%
#single world
my_first_string='algebra'
my_first_string
print(my_first_string)
# Out:
# algebra

# %%
# we can also double quote
my_string = "string built with double quotes"
print(my_string)   # use the print command
# Out:
# string built with double quotes

# %%
# Be careful with quotes!
sentence= 'I'm using single quotes, but this will create an error'
print(sentence)
# Out:
#   Cell In[6], line 2
#     sentence= 'I'm using single quotes, but this will create an error'
#                                                                      ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
sentence= "I'm using single quotes, but this will create an error"
print(sentence)
# Out:
# I'm using single quotes, but this will create an error

# %%
hash = '#'
print(hash)
# Out:
# #

# %%
type(hash)
# Out:
# str

# %%
# we can simply declare a string
'Deep Learning'
# Out:
# 'Deep Learning'

# %%
print('Linear Algebra')
print('Calculus')
print('Use \n to print anew line')
print('\n')
print('See what \n I mean?')
# Out:
# Linear Algebra
# Calculus
# Use
#  to print anew line
#
#
# See what
#  I mean?

# %%
algo = 'regres sion '
len(algo)
# Out:
# 12

# %%
# Assign string as a string
string = 'Principal Component Analysis'

# %%
# Assign a list to an variable named my_list
my_list = [1,2,3,4]

# %%
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
type(my_list)
# Out:
# list

# %%
my_list = ['A string',23,100.232,'0', True]

# %%
my_list
# Out:
# ['A string', 23, 100.232, '0', True]

# %%
len(my_list)
# Out:
# 5

# %%
name = "akash"
print(name.upper())
# Out:
# AKASH

# %%
str = "python programing"
print("First Character:",str[0])
print("Last Character:",str[-1])
# Out:
# First Character: p
# Last Character: g

# %%
text = "python progrming"
print("total charecter:",len(text))
# Out:
# total charecter: 16

# %%
msg = "hello world"
print(msg.title())
# Out:
# Hello World

# %%
str = "Python program is tough"
print(str.replace(" ", "-"))
# Out:
# Python-program-is-tough

# %%
bird = "peacock" 
print(bird.count("c"))
# Out:
# 2

# %%
movie = "drishyam"
print(movie.lower())
# Out:
# drishyam

# %%
text = "    Hello kerala"
print(text.strip())
# Out:
# Hello kerala

# %%
bird ="peacock,pigeon,kingfisher"
print(bird.split(","))
# Out:
# ['peacock', 'pigeon', 'kingfisher']

# %%
subjects = ["maths","science","english","history","computer"]
print(subjects[0])
# Out:
# maths

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[-1])
# Out:
# 50

# %%
brands = ["Samsung", "Apple", "Nokia"]
brands.append("OnePlus")
print(brands)
# Out:
# ['Samsung', 'Apple', 'Nokia', 'OnePlus']

# %%
students = ["Anu", "Rahul", "Meera", "Akhil", "Neha"]
print(len(students))
# Out:
# 5

# %%
# 5. Create a list [10, 20, 30, 40] and change 30 to 35
nums = [10, 20, 30, 40]
nums[2] = 35
print(nums)
# Out:
# [10, 20, 35, 40]

# %%
subjects2 = ["Science", "Maths", "English"]
subjects2.remove("Maths")
print(subjects2)
# Out:
# ['Science', 'English']

# %%
# 7. Create a list of numbers and print the maximum value
values = [12, 45, 7, 89, 23]
print(max(values))
# Out:
# 89

# %%
cities = ["Kochi", "Delhi", "Mumbai", "Chennai", "Bangalore"]
cities.sort()
print(cities)
# Out:
# ['Bangalore', 'Chennai', 'Delhi', 'Kochi', 'Mumbai']

# %%
list1 = [1, 2, 3]
list2 = [4, 5, 6]
combined = list1 + list2
print(combined)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
items = ["book", "pen", "pencil"]

if "pen" in items:
    print("pen exists in the list")
else:
    print("pen does not exist in the list")
# Out:
# pen exists in the list

# %%
numbers = (10 , 20 , 30 , 40 , 50)
print(numbers[0])
# Out:
# 10

# %%
students = ("Akash","Ajmal","Jobin","vaishnav","Aanadhu")
print(students[-2])
# Out:
# vaishnav

# %%
num = (10 , 20 , 30 , 40 , 50)
print(len(num))
# Out:
# 5

# %%
numbers = ("one","two","three","four")
print("three" in numbers)
# Out:
# True

# %%
numbers = (10 , 20 , 30 , 40)
print(max(numbers))
# Out:
# 40

# %%
num = (1 , 2 , 3 , 4)
print(num.count(4))
# Out:
# 1

# %%
t1 = (1,2)
t2 = (3,4)
t3 = t1 + t2
print(t3)
# Out:
# (1, 2, 3, 4)

# %%
countries = ("India","London","Russian","America")
print(sorted(countries))
# Out:
# ['America', 'India', 'London', 'Russian']

# %%
language = ("python", "java", "c++")
print(language.index("c++"))
# Out:
# 2

# %%
numbers = {1, 2, 3, 4, 5}
print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
states = {"Kerala","Tamil Nadu"}

states.add("Goa")
print(states)
# Out:
# {'Goa', 'Kerala', 'Tamil Nadu'}

# %%
subjects = {"Maths", "Science", "English"}
subjects.remove("Science")
print(subjects)
# Out:
# {'English', 'Maths'}

# %%
nums = {10, 20, 30, 40, 50}
print(50 in nums)
# Out:
# True

# %%
a = {1, 2, 3}
b = {2, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
x = {1, 2, 3}
y = {2, 3, 4}
print(x.intersection(y))
# Out:
# {2, 3}

# %%
brands = {"Samsung", "Apple", "Nokia", "Oneplus"}
print(len(brands))
# Out:
# 4

# %%
s3 = {1, 2, 3, 4}
s3.clear()
print(s3)
# Out:
# set()

# %%
s4 = {10, 20, 30}
s4.update([40, 50, 60])
print(s4)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
lst = [1, 2, 2, 3, 3, 4]
print(set(lst))
# Out:
# {1, 2, 3, 4}

# %%
person = {"name": "Rahul", "age": 18}
print(person["name"])
print(person["age"])
# Out:
# Rahul
# 18

# %%
student = {"name": "Akash", "class": 10, "roll": 25}
print(student["name"])
# Out:
# Akash

# %%
marks = {"Math": 90, "Science": 85, "English": 88}
print(marks.keys())
# Out:
# dict_keys(['Math', 'Science', 'English'])

# %%
info = {"name": "Akash", "age": 19}
info["city"] = "kollam"
print(info)
# Out:
# {'name': 'Akash', 'age': 19, 'city': 'kollam'}

# %%
d = {"a": 10, "b": 20}
d["b"] = 50
print(a)
# Out:
# {1, 2, 3}

# %%
details = {"name": "Ajmal", "age": 19}
details.pop("age")
print(details)
# Out:
# {'name': 'Ajmal'}

# %%
employee = {"name": "Akash", "salary": 50000, "department": "IT"}
print(employee.values())
# Out:
# dict_values(['Akash', 50000, 'IT'])

# %%
employee = {
    "name": "Akash",
    "salary": 20000
}

if "salary" in employee:
    print("key exists")
else:
    print("key does not exists")
# Out:
# key exists

# %%
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

d1.update(d2)

print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
student = {
    "name": "Akash",
    "age": 20,
    "course": "Bsc"
}

print(len(student))
# Out:
# 3
